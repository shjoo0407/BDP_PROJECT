# %%
import pandas as pd

# %%
#2020
data1 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/대여이력 정보/data2020_1.csv")
data2 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/대여이력 정보/data2020_2.csv")
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_69875/3014896354.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/대여이력 정보/data2020_2.csv")

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', '자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시',
#        '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Unnamed: 0', '자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시',
#        '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],
#       dtype='object')

# %%
data1.drop(['Unnamed: 0'], axis = 1, inplace = True)
data2.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
data1.columns
# Out:
# Index(['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호',
#        '반납대여소명', '반납거치대', '이용시간', '이용거리'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호',
#        '반납대여소명', '반납거치대', '이용시간', '이용거리'],
#       dtype='object')

# %%
df = pd.concat([data1, data2], ignore_index=True)
df
# Out:
#               자전거번호                 대여일시  대여소번호               대여대여소명 대여거치대  \
# 0         SPB-19866        2020.5.1 0:01   1706               기업은행 앞     5
# 1         SPB-07309        2020.5.1 0:00    585      성수2가1동 공영주차장 인근     4
# 2         SPB-09425        2020.5.1 0:02   1155              기쁜우리복지관    10
# 3         SPB-13624        2020.5.1 0:01   2396  영동3교 북단(우성캐릭터 앞 보도)     1
# 4         SPB-32740        2020.5.1 0:00    917             녹번역 4번출구     0
# ...             ...                  ...    ...                  ...   ...
# 16220852  SPB-32746  2020-12-31 20:36:25   1009       천호역4번출구(현대백화점)     0
# 16220853  SPB-30390  2020-12-31 22:51:36   1965      삼환로즈빌아파트 105동 옆     0
# 16220854  SPB-50439  2020-12-31 22:56:32   1964              원메디타운 앞     0
# 16220855  SPB-37080  2020-12-31 22:18:07    130      신촌역(2호선) 7번출구 앞     0
# 16220856  SPB-33700  2020-12-31 21:52:24   1735    도봉역 1,2번 출구사이 건너편     0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df["대여일시"]["2020.6.1 0:03"]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# ...

# %%
df.to_csv("data2020.csv", encoding="utf-8-sig")

# %%
#2020
# data1 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/대여이력 정보/data/data2019.csv")
data1 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/대여이력 정보/data/data2019.csv")
# data2 = pd.read_csv("/Users/janghyun/Downloads/공공자전거 대여이력 정보_202006.csv")
# data3 = pd.read_csv("/Users/janghyun/Downloads/공공자전거 대여이력 정보_2020.04.csv")
# data4 = pd.read_csv("/Users/janghyun/Downloads/공공자전거 대여이력 정보_2020.03.csv")
# data5 = pd.read_csv("/Users/janghyun/Downloads/공공자전거 대여이력 정보_2020.02.csv")
# data6 = pd.read_csv("/Users/janghyun/Downloads/공공자전거 대여이력 정보_2020.01.csv")

# %%
data1
# Out:
#          Unnamed: 0      자전거번호                 대여일시  대여소번호            대여대여소명  \
# 0                 0  SPB-12844        2019.5.1 0:00   1224     아시아지하보도 2번 출구
# 1                 1  SPB-15490        2019.5.1 0:01    521     왕십리역 11번 출구 앞
# 2                 2  SPB-18475        2019.5.1 0:01    364        창신역 1번출구 앞
# 3                 3  SPB-11204        2019.5.1 0:01   1983          구로동롯데아파트
# 4                 4  SPB-15403        2019.5.1 0:02   2235         KT 서초지사 앞
# ...             ...        ...                  ...    ...               ...
# 2881379     2881379  SPB-14865  2019-03-31 23:47:30    159         이대역 4번 출구
# 2881380     2881380  SPB-14576  2019-03-31 21:31:33   1249          아주중학교건너편
# 2881381     2881381  SPB-05879  2019-03-31 21:50:16   1248            방이초등학교
# 2881382     2881382  SPB-05239  2019-03-31 07:35:10   1734  쌍문현대1차아파트 108동 앞
# 2881383     2881383  SPB-16830  2019-03-31 22:09:01    117             홍은사거리
#
# ...

# %%
data2.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data3.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data4.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data5.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data6.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']

# %%
# data1.drop(['Unnamed: 0'], axis = 1, inplace = True)

df = pd.concat([data1, data2, data3, data4, data5, data6], ignore_index=True)
df
# Out:
#               자전거번호             대여일시  대여소번호               대여대여소명 대여거치대  \
# 0         SPB-19866    2020.5.1 0:01   1706               기업은행 앞     5
# 1         SPB-07309    2020.5.1 0:00    585      성수2가1동 공영주차장 인근     4
# 2         SPB-09425    2020.5.1 0:02   1155              기쁜우리복지관    10
# 3         SPB-13624    2020.5.1 0:01   2396  영동3교 북단(우성캐릭터 앞 보도)     1
# 4         SPB-32740    2020.5.1 0:00    917             녹번역 4번출구     0
# ...             ...              ...    ...                  ...   ...
# 20866025  SPB-13688  2020.1.31 23:45    178               증산3교 앞     3
# 20866026  SPB-22994  2020.1.31 23:35    135           명물길 원형무대 앞     4
# 20866027  SPB-08546  2020.1.31 23:41    237         보라매 두산위브 건너편    17
# 20866028  SPB-13247  2020.1.31 23:52   2377           수서역 5번출구 뒤     4
# 20866029  SPB-06034  2020.1.31 23:55    363         신설동역 11번출구 뒤     3
#
#                      반납일시 반납대여소번호           반납대여소명  반납거치대  이용시간    이용거리
# ...

# %%
df.sort_values("대여일시")
print(len(df))
df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
print(len(df))
# Out:
# 20866030
# 20866030

# %%
df = df[0:]
# Out:
#               자전거번호             대여일시  대여소번호               대여대여소명 대여거치대  \
# 1         SPB-07309    2020.5.1 0:00    585      성수2가1동 공영주차장 인근     4
# 2         SPB-09425    2020.5.1 0:02   1155              기쁜우리복지관    10
# 3         SPB-13624    2020.5.1 0:01   2396  영동3교 북단(우성캐릭터 앞 보도)     1
# 4         SPB-32740    2020.5.1 0:00    917             녹번역 4번출구     0
# 5         SPB-32384    2020.5.1 0:00   2259       잠원역 3번-4번 출구사이     0
# ...             ...              ...    ...                  ...   ...
# 20866025  SPB-13688  2020.1.31 23:45    178               증산3교 앞     3
# 20866026  SPB-22994  2020.1.31 23:35    135           명물길 원형무대 앞     4
# 20866027  SPB-08546  2020.1.31 23:41    237         보라매 두산위브 건너편    17
# 20866028  SPB-13247  2020.1.31 23:52   2377           수서역 5번출구 뒤     4
# 20866029  SPB-06034  2020.1.31 23:55    363         신설동역 11번출구 뒤     3
#
#                      반납일시 반납대여소번호           반납대여소명  반납거치대  이용시간    이용거리
# ...

# %%
df.to_csv("data2020.csv", encoding="utf-8-sig")

# %%
len(data1)
# Out:
# 16220857

# %%
data1 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201911_2.csv")
data2 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201911_1.csv")
data3 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201910_3.csv")
data4 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201910_2.csv")
data5 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201910_1.csv")
data6 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201909_3.csv")
data7 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201909_2.csv")
data8 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201909_1.csv")
data9 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201908_3.csv")
data10 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201908_2.csv")
data11 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201908_1.csv")
data12 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201907_3.csv")
data13 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201907_2.csv")
data13 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201907_1.csv")
data14 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201906_3.csv")
data15 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201906_2.csv")
data16 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201906_1.csv")
data17 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201905.csv")
data18 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201904.csv")
data19 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201903.csv")
data20 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201902.csv")
data21 = pd.read_csv("/Users/janghyun/Downloads/서울특별시 공공자전거 대여정보_201901.csv")
data22 = pd.read_csv("/Users/janghyun/Downloads/공공자전거 대여이력 정보_201912.csv")
# data23 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/대여이력 정보/data/data2019.csv")

# %%
#columns 통일
data3.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data4.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data5.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data6.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data7.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data8.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data9.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data10.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data11.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data12.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data13.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data14.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data15.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data16.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data17.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data18.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data19.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data20.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data21.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data22.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data1.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data2.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']

# %%
data = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, 
                  data13, data14, data15, data16, data17, data18, data19, data20, data21, data22], ignore_index=True)
print("전체 데이터 개수: ", len(data))

print("데이터 구조: ")
data
# Out:
# 전체 데이터 개수:  16133536
# 데이터 구조:
#               자전거번호              대여일시  대여소번호          대여대여소명  대여거치대  \
# 0         SPB-04392  2019.11.28 23:07   2377      수서역 5번출구 뒤      9
# 1         SPB-23502  2019.11.28 22:43   2613           잠실나들목      3
# 2         SPB-11498   2019.11.29 0:04   1256     문정현대아파트 교차로      6
# 3         SPB-16665   2019.11.29 0:02   1278        송파구청 교차로      9
# 4         SPB-14688   2019.11.29 0:17   1230        송파중학교 정문      5
# ...             ...               ...    ...             ...    ...
# 16133531  SPB-18675  2019.12.31 23:38    430   KEB하나은행 장충동지점      5
# 16133532  SPB-13564  2019.12.31 16:08   1673        노원역?5번출구      6
# 16133533  SPB-11208  2019.12.31 21:11   2307   압구정 한양 3차 아파트      5
# 16133534  SPB-23946  2019.12.31 23:59    327          낙원상가 옆      1
# 16133535  SPB-17909  2019.12.31 20:11    500  어린이대공원역 3번출구 앞      9
#
#                       반납일시  반납대여소번호          반납대여소명  반납거치대  이용시간   이용거리
# ...

# %%
data = data.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)

# %%
data
# Out:
#               자전거번호              대여일시  대여소번호          대여대여소명  대여거치대  \
# 0         SPB-04392  2019.11.28 23:07   2377      수서역 5번출구 뒤      9
# 1         SPB-23502  2019.11.28 22:43   2613           잠실나들목      3
# 2         SPB-11498   2019.11.29 0:04   1256     문정현대아파트 교차로      6
# 3         SPB-16665   2019.11.29 0:02   1278        송파구청 교차로      9
# 4         SPB-14688   2019.11.29 0:17   1230        송파중학교 정문      5
# ...             ...               ...    ...             ...    ...
# 16133531  SPB-18675  2019.12.31 23:38    430   KEB하나은행 장충동지점      5
# 16133532  SPB-13564  2019.12.31 16:08   1673        노원역?5번출구      6
# 16133533  SPB-11208  2019.12.31 21:11   2307   압구정 한양 3차 아파트      5
# 16133534  SPB-23946  2019.12.31 23:59    327          낙원상가 옆      1
# 16133535  SPB-17909  2019.12.31 20:11    500  어린이대공원역 3번출구 앞      9
#
#                       반납일시  반납대여소번호          반납대여소명  반납거치대  이용시간   이용거리
# 0         2019.11.28 23:18     1203       밀리아나2빌딩 앞      5    11   1980
# ...

# %%
data["date"]=pd.to_datetime(data['대여일시'].str.strip(), format="%Y-%m-%d %H:%M", errors='coerce')

# %%
data.sort_values("date")
# Out:
#               자전거번호              대여일시  대여소번호          대여대여소명  대여거치대  \
# 14798675  SPB-15831     2019.1.1 0:00   1178      개화산역 2번 출구      9
# 14798840  SPB-18989     2019.1.1 0:00   2361        압구정역 교차로      3
# 14798711  SPB-16623     2019.1.1 0:00   1911      구로디지털단지역 앞     10
# 14798641  SPB-10632     2019.1.1 0:00   1421        신내역 4번출구      3
# 14798665  SPB-18337     2019.1.1 0:01    815  LIG강촌아파트 103동앞      3
# ...             ...               ...    ...             ...    ...
# 16133395  SPB-18983  2019.12.31 23:59   1904    도림천역 1번 출구 앞      4
# 16133534  SPB-23946  2019.12.31 23:59    327          낙원상가 옆      1
# 16133405  SPB-21631  2019.12.31 23:59    582         경일중학교 앞      1
# 16133438  SPB-06000  2019.12.31 23:59    579        마장역 4번출구      5
# 16133413  SPB-10863  2019.12.31 23:59   3104   e편한세상 신촌4단지 앞     12
#
#                    반납일시  반납대여소번호                   반납대여소명  반납거치대  이용시간   이용거리  \
# ...

# %%
data.drop(['date'], axis = 1, inplace = True)

# %%
data.to_csv("data2019.csv", encoding="utf-8-sig")

# %%
data.columns
# Out:
# Index(['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호',
#        '반납대여소명', '반납거치대', '이용시간', '이용거리'],
#       dtype='object')

# %%
data = pd.read_csv("/Users/janghyun/Desktop/BDP/data/대여이력 정보/data/data2020.csv")

# %%
data
