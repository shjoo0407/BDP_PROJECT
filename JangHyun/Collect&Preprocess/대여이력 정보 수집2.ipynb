# %%
import pandas as pd

# %%
data1 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2018.10.csv")
data2 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.5.csv")
data3 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.6_1.csv")
data4 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.6_2.csv")
data5 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.6_3.csv")
data6 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.7_1.csv")
data7 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.7_2.csv")
data8 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.7_3.csv")
data9 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.8_1.csv")
data10 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.8_2.csv")
data11 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.8_3.csv")
data12 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.9_1.csv")
data13 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.9_2.csv")
data14 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.9_3.csv")
data15 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.10_1.csv")
data16 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.10_2.csv")
data17 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.10_3.csv")
data18 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.11_1.csv")
data19 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.11_2.csv")
data20 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2019.12.csv")
data21 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.1.csv")
data22 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.2.csv")
data23 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.3.csv")
data24 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.4.csv")
data25 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.5.csv")
data26 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.6_1.csv")
data27 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.6_2.csv")
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_54504/172804426.py:21: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data21 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.1.csv")
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_54504/172804426.py:22: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data22 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.2.csv")
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_54504/172804426.py:23: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data23 = pd.read_csv("/Users/janghyun/Desktop/BDP/data/고장신고 내역/2020.3.csv")
# ...

# %%
#data2 누락 columns 추가
add2 = data2.columns
data2.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data2.columns
data2.loc[0] = add2

#columns 통일
data3.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data4.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data5.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data6.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data7.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data8.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data9.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data10.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data11.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data12.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data13.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data14.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data15.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data16.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data17.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data18.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data19.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data20.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data21.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data22.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data23.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data24.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data25.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data26.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']
data27.columns=['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호','반납대여소명', '반납거치대', '이용시간', '이용거리']

# %%
data = pd.concat(df_list, ignore_index = True)
data

# %%
data.reset_index(drop=True, inplace=True)

# %%
data = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, 
                  data13, data14, data15, data16, data17, data18, data19, data20, data25, data26, data27], ignore_index=True)
print("전체 데이터 개수: ", len(data))

print("데이터 구조: ")
data
# Out:
# 전체 데이터 개수:  18246452
# 데이터 구조:
#               자전거번호             대여일시 대여소번호          대여대여소명 대여거치대  \
# 0         SPB-13621   2018.10.1 0:02   127         현대벤처빌 앞     9
# 1         SPB-10560   2018.10.1 0:01  1326       상월곡역 1번출구     5
# 2         SPB-16256   2018.10.1 0:00   815  LIG강촌아파트 103동앞    10
# 3         SPB-07969   2018.10.1 0:01  1308   안암로터리 버스정류장 앞    12
# 4         SPB-10866   2018.10.1 0:02   575       중앙농협 중곡지점     9
# ...             ...              ...   ...             ...   ...
# 18246447  SPB-32717  2020.6.16 22:55   913         이마트 은평점     0
# 18246448  SPB-15338  2020.6.16 22:46   167        연가초등학교 옆    13
# 18246449  SPB-31982  2020.6.16 22:48   559  왕십리역 4번 출구 건너편     0
# 18246450  SPB-24981  2020.6.16 22:10  1168     마곡엠밸리10단지 앞     9
# 18246451  SPB-14853  2020.6.16 22:35  2115      관악농협농산물백화점    13
#
#                      반납일시 반납대여소번호       반납대여소명 반납거치대 이용시간     이용거리
# 0          2018.10.1 0:04     124   서강대 정문 건너편    18    1      350
# ...

# %%
#csv 파일로 저장
data.to_csv("대여이력 정보2.csv", encoding="utf-8-sig")

# %%
#data 확인
df = pd.read_csv("/Users/janghyun/Desktop/BDP/data/대여이력 정보2.csv")
df
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_54504/3860841914.py:1: DtypeWarning: Columns (3,5,7,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/janghyun/Desktop/BDP/data/대여이력 정보2.csv")
#           Unnamed: 0      자전거번호             대여일시 대여소번호          대여대여소명 대여거치대  \
# 0                  0  SPB-13621   2018.10.1 0:02   127         현대벤처빌 앞     9
# 1                  1  SPB-10560   2018.10.1 0:01  1326       상월곡역 1번출구     5
# 2                  2  SPB-16256   2018.10.1 0:00   815  LIG강촌아파트 103동앞    10
# 3                  3  SPB-07969   2018.10.1 0:01  1308   안암로터리 버스정류장 앞    12
# 4                  4  SPB-10866   2018.10.1 0:02   575       중앙농협 중곡지점     9
# ...              ...        ...              ...   ...             ...   ...
# 18246447    18246447  SPB-32717  2020.6.16 22:55   913         이마트 은평점     0
# 18246448    18246448  SPB-15338  2020.6.16 22:46   167        연가초등학교 옆    13
# ...

# %%
#결측치 확인
df.isnull().count()
# Out:
# Unnamed: 0    18246452
# 자전거번호         18246452
# 대여일시          18246452
# 대여소번호         18246452
# 대여대여소명        18246452
# 대여거치대         18246452
# 반납일시          18246452
# 반납대여소번호       18246452
# 반납대여소명        18246452
# 반납거치대         18246452
# 이용시간          18246452
# 이용거리          18246452
# dtype: int64
