# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/janghyun/Desktop/BDP/data/코드/data2020_pre.csv", index_col=0)

# %%
df
# Out:
#               자전거번호  이용시간         이용거리  year  month
# 0         SPB-19866   1.0   330.000000  2020      5
# 3         SPB-13624   2.0  1016.486847  2020      5
# 4         SPB-32740   5.0  1371.829785  2020      5
# 5         SPB-32384   5.0  1371.829785  2020      5
# 6         SPB-33241   5.0  1371.829785  2020      5
# ...             ...   ...          ...   ...    ...
# 20866025  SPB-13688  13.0  2319.410950  2020      1
# 20866026  SPB-22994  21.0  3670.000000  2020      1
# 20866027  SPB-08546  17.0  3140.000000  2020      1
# 20866028  SPB-13247   6.0   860.000000  2020      1
# 20866029  SPB-06034   3.0   700.000000  2020      1
#
# [20354012 rows x 5 columns]

# %%
df.columns = ["ID", "Time", "Distance", "Year", "Month"]

# %%
df["Distance"] = df["Distance"].astype(int)
df["Time"] = df["Time"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20354012 entries, 0 to 20866029
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   ID        object
#  1   Time      int64
#  2   Distance  int64
#  3   Year      int64
#  4   Month     int64
# dtypes: int64(4), object(1)
# memory usage: 931.7+ MB

# %%
month = df['Month'] == 1
df_1 = df[month]
month = df['Month'] == 2
df_2 = df[month]
month = df['Month'] == 3
df_3 = df[month]
month = df['Month'] == 4
df_4 = df[month]
month = df['Month'] == 5
df_5 = df[month]
month = df['Month'] == 6
df_6 = df[month]
month = df['Month'] == 7
df_7 = df[month]
month = df['Month'] == 8
df_8 = df[month]
month = df['Month'] == 9
df_9 = df[month]
month = df['Month'] == 10
df_10 = df[month]
month = df['Month'] == 11
df_11 = df[month]
month = df['Month'] == 12
df_12 = df[month]

# %%
df_1['Count'] = 1
df_1 = df_1.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_1
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1557467535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1557467535.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_1 = df_1.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00025   376     63280     22
# 1      SPB-00036   759     91570     38
# 2      SPB-00040  1089    161660     54
# 3      SPB-00043   905    120840     61
# 4      SPB-00050  1629    212324     84
# ...          ...   ...       ...    ...
# ...

# %%
df_2['Count'] = 1
df_2 = df_2.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_2
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/3251557880.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/3251557880.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_2 = df_2.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00004   639     68280     15
# 1      SPB-00025   347     27840     12
# 2      SPB-00036   804    124660     36
# 3      SPB-00040   443     68730     25
# 4      SPB-00043   451     64040     19
# ...          ...   ...       ...    ...
# ...

# %%
df_3['Count'] = 1
df_3 = df_3.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_3
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1755933121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1755933121.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_3 = df_3.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00004  2177    302965     63
# 1      SPB-00025  3221    446380    107
# 2      SPB-00036  3447    499420     84
# 3      SPB-00040   829     97740     16
# 4      SPB-00043  1422    201190     44
# ...          ...   ...       ...    ...
# ...

# %%
df_4['Count'] = 1
df_4 = df_4.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_4
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/4142602345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/4142602345.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_4 = df_4.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00003  2742    387111     80
# 1      SPB-00025  3802    658210    101
# 2      SPB-00036  3052    427750     92
# 3      SPB-00050  1339    154840     45
# 4      SPB-00071  4257    624970    104
# ...          ...   ...       ...    ...
# ...

# %%
df_5['Count'] = 1
df_5 = df_5.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_5
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/643996237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/643996237.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_5 = df_5.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00025  2445    375590     81
# 1      SPB-00036   635     78848     14
# 2      SPB-00102  3513    507256    117
# 3      SPB-00112  3527    491780     95
# 4      SPB-00160   230     36300     10
# ...          ...   ...       ...    ...
# ...

# %%
df_6['Count'] = 1
df_6 = df_6.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_6
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1249958004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1249958004.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_6 = df_6.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00025  7364   1271339    245
# 1      SPB-00036   298     38940      6
# 2      SPB-00050  3617    659314    124
# 3      SPB-00071   357     59910     21
# 4      SPB-00102  3644    528234    124
# ...          ...   ...       ...    ...
# ...

# %%
df_7['Count'] = 1
df_7 = df_7.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_7
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1500036073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_7['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1500036073.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_7 = df_7.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00025   436     60172     14
# 1      SPB-00036   724     81513     25
# 2      SPB-00050  1585    232575     55
# 3      SPB-00102   604     93357     28
# 4      SPB-00165  3705    529806    111
# ...          ...   ...       ...    ...
# ...

# %%
df_8['Count'] = 1
df_8 = df_8.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_8
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/695152778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_8['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/695152778.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_8 = df_8.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00025   311     47100     14
# 1      SPB-00050   291     15110      7
# 2      SPB-00102  1989    288572     68
# 3      SPB-00165   742    105028     22
# 4      SPB-00236   605     91790     20
# ...          ...   ...       ...    ...
# ...

# %%
df_9['Count'] = 1
df_9 = df_9.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_9
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/921274121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_9['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/921274121.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_9 = df_9.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00025  1066    142480     29
# 1      SPB-00102  1146    162230     34
# 2      SPB-00285   139     20720      4
# 3      SPB-00290  2895    397440     70
# 4      SPB-00291  2429    383961     85
# ...          ...   ...       ...    ...
# ...

# %%
df_10['Count'] = 1
df_10 = df_10.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_10
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1171744134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/1171744134.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_10 = df_10.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00102  1021    154431     43
# 1      SPB-00241    21      4045      2
# 2      SPB-00291  1291    224030     44
# 3      SPB-00372   238     32865      6
# 4      SPB-00385   515     60251     35
# ...          ...   ...       ...    ...
# ...

# %%
df_11['Count'] = 1
df_11 = df_11.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_11
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/494504271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_11['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/494504271.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_11 = df_11.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00025    24      5390      2
# 1      SPB-00241   207     31359     14
# 2      SPB-00290    95     14369      4
# 3      SPB-00372     9      1845      1
# 4      SPB-00397   767     83477     33
# ...          ...   ...       ...    ...
# ...

# %%
df_12['Count'] = 1
df_12 = df_12.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
df_12
# Out:
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/783448027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12['Count'] = 1
# /var/folders/qy/_42009_n085fc984bjdc5v580000gn/T/ipykernel_1721/783448027.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_12 = df_12.groupby("ID")["Time", "Distance", "Count"].sum().reset_index()
#               ID  Time  Distance  Count
# 0      SPB-00241   204     24441     13
# 1      SPB-00291   451     75850      9
# 2      SPB-00385    29      6210      3
# 3      SPB-00397    28      4180      2
# 4      SPB-00403   107      6440      5
# ...          ...   ...       ...    ...
# ...

# %%
df_1.to_csv("2020_1.csv", encoding="utf-8-sig")
df_2.to_csv("2020_2.csv", encoding="utf-8-sig")
df_3.to_csv("2020_3.csv", encoding="utf-8-sig")
df_4.to_csv("2020_4.csv", encoding="utf-8-sig")
df_5.to_csv("2020_5.csv", encoding="utf-8-sig")
df_6.to_csv("2020_6.csv", encoding="utf-8-sig")
df_7.to_csv("2020_7.csv", encoding="utf-8-sig")
df_8.to_csv("2020_8.csv", encoding="utf-8-sig")
df_9.to_csv("2020_9.csv", encoding="utf-8-sig")
df_10.to_csv("2020_10.csv", encoding="utf-8-sig")
df_11.to_csv("2020_11.csv", encoding="utf-8-sig")
df_12.to_csv("2020_12.csv", encoding="utf-8-sig")
