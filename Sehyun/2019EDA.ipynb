# %%
from google.colab import drive
drive.mount('/content.drive')
# Out:
# Mounted at /content.drive

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content.drive/MyDrive/data/BDP_PROJECT/2019/data2019.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      자전거번호                 대여일시  대여소번호  \
# 0           0           0.0  SPB-10632  2019-01-01 00:00:44   1421
# 1           1           1.0  SPB-10957  2019-01-01 00:02:16   1408
# 2           2           2.0  SPB-16067  2019-01-01 00:04:12    347
# 3           3           3.0  SPB-17170  2019-01-01 00:03:09    615
# 4           4           4.0  SPB-14130  2019-01-01 00:01:44   1177
#
#               대여대여소명  대여거치대                 반납일시  반납대여소번호        반납대여소명  \
# 0           신내역 4번출구      3  2019-01-01 00:03:53     1420      신내어울공원 앞
# 1         먹골역 6번출구 앞      3  2019-01-01 00:07:07     1433      중화역 2번출구
# 2  동대문역사문화공원역 9번출구 앞     17  2019-01-01 00:07:07      387    훈련원공원주차장 앞
# 3   용두동 래미안허브리츠아파트 앞      4  2019-01-01 00:07:27      612  시립동부병원 앞 사거리
# 4             수명중?고교      7  2019-01-01 00:08:09     1152        마곡역교차로
#
#    반납거치대  이용시간    이용거리
# 0     13     2   580.0
# 1      4     4  1020.0
# 2      1     2   550.0
# 3     14     3   700.0
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# Unnamed: 0.1    1048575
# 자전거번호                 0
# 대여일시                  0
# 대여소번호                 0
# 대여대여소명                0
# 대여거치대                 0
# 반납일시                  0
# 반납대여소번호               0
# 반납대여소명                0
# 반납거치대                 0
# 이용시간                  0
# 이용거리                  0
# dtype: int64

# %%
data.sort_values('이용거리')
# Out:
#          Unnamed: 0  Unnamed: 0.1      자전거번호                 대여일시  대여소번호  \
# 328728       328728      328728.0  SPB-03904  2019-01-22 21:36:14    104
# 554557       554557       68856.0  SPB-01264  2019-02-07 12:32:18   1218
# 1583418     1583418      635745.0  SPB-04430  2019-03-24 12:51:35   3509
# 44074         44074       44074.0  SPB-13872  2019-01-04 10:41:08    557
# 2424017      591208           NaN  SPB-09506       2019.5.9 12:46    201
# ...             ...           ...        ...                  ...    ...
# 2678610      845801           NaN  SPB-15109      2019.5.12 20:12    802
# 2507695      674886           NaN  SPB-15135      2019.5.10 16:30    513
# 2838480     1005671           NaN  SPB-14934      2019.5.14 22:43    152
# 2710117      877308           NaN  SPB-15167       2019.5.13 8:56   1009
# 2401797      568988           NaN  SPB-13890       2019.5.8 23:34   1449
#
#                   대여대여소명  대여거치대                 반납일시  반납대여소번호  \
# ...

# %%
data['이용거리'].value_counts()
# Out:
# 0.0         42584
# 910.0       11117
# 1100.0      10781
# 900.0       10743
# 980.0       10682
#             ...
# 234160.0        1
# 86750.0         1
# 82790.0         1
# 203750.0        1
# 130480.0        1
# Name: 이용거리, Length: 10273, dtype: int64

# %%
data[(data['이용시간']==0)&(data['이용거리']>100)].sort_values('이용거리')
# Out:
#          Unnamed: 0  Unnamed: 0.1      자전거번호             대여일시  대여소번호  \
# 2516877      684068           NaN  SPB-10122  2019.5.10 17:48    334
# 1935484      102675           NaN  SPB-12802   2019.5.2 14:33   2279
# 2634645      801836           NaN  SPB-19066  2019.5.12 10:20   1299
# 2359467      526658           NaN  SPB-15072   2019.5.8 14:43   2110
# 1897686       64877           NaN  SPB-06430   2019.5.1 21:19    518
# ...             ...           ...        ...              ...    ...
# 2689955      857146           NaN  SPB-12310  2019.5.12 21:37   2259
# 2383128      550319           NaN  SPB-07975   2019.5.8 18:09   1998
# 2506793      673984           NaN  SPB-18151  2019.5.10 16:29    737
# 2046107      213298           NaN  SPB-20162   2019.5.3 20:36    154
# 2803919      971110           NaN  SPB-20131  2019.5.14 17:45    312
#
#                     대여대여소명  대여거치대             반납일시  반납대여소번호        반납대여소명  \
# ...

# %%
new_data = data[(data['이용시간']>10)|(data["이용거리"]!=0)].sort_values('이용시간')
new_data.head()
# Out:
#          Unnamed: 0  Unnamed: 0.1      자전거번호             대여일시  대여소번호  \
# 1852800       19991           NaN  SPB-14204   2019.5.1 12:48    591
# 2857517     1024708           NaN  SPB-17654   2019.5.15 8:55    213
# 2208030      375221           NaN  SPB-19813   2019.5.6 14:08   2102
# 2359467      526658           NaN  SPB-15072   2019.5.8 14:43   2110
# 2747273      914464           NaN  SPB-01140  2019.5.13 20:11    502
#
#                 대여대여소명  대여거치대             반납일시  반납대여소번호      반납대여소명  반납거치대  \
# 1852800    건국대학교 (행정관)      4   2019.5.1 12:50      592  건국대학교 학생회관      1
# 2857517            KT앞     14   2019.5.15 8:56      214     금융감독원 앞     14
# 2208030        봉림교 교통섬      1   2019.5.6 14:18     2183        동방1교      1
# 2359467      조원동 미성아파트      5   2019.5.8 14:44     1955   디지털입구 교차로      7
# 2747273  뚝섬유원지역 1번출구 앞     12  2019.5.13 20:12      588     뚝섬 유원지역      4
#
#          이용시간    이용거리
# 1852800     0   210.0
# 2857517     0   180.0
# 2208030     0  2350.0
# ...
