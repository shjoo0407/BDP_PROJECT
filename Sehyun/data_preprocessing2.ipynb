# %%
from google.colab import drive
drive.mount('/content.drive')
# Out:
# Mounted at /content.drive

# %%
# import
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content.drive/MyDrive/data/BDP_PROJECT/tmp.csv")
data.head()
# Out:
#    Unnamed: 0      자전거번호                 대여일시  이용시간         이용거리
# 0           0  SPB-36089  2020-07-01 00:00:54   2.0  1030.840002
# 1           1  SPB-11402  2020-07-01 00:00:15   3.0   450.000000
# 2           2  SPB-36935  2020-07-01 00:01:02   3.0  1147.939279
# 3           3  SPB-35374  2020-07-01 00:00:04   4.0  1265.038556
# 4           6  SPB-32502  2020-07-01 00:00:40   4.0  1265.038556
