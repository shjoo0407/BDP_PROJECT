# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression

# %%
#모델을 생성하고, 그 안에 속성들과 레이블을 fit 시킨다.

model = LogisticRegression()
model.fit(features,labels)

# %%
model.predict(features)
