# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/data/BDP_PROJECT/2020/data2020.csv")
# Out:
# C:\Users\shjoo\AppData\Local\Temp\ipykernel_23208\3684344012.py:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("C:/data/BDP_PROJECT/2020/data2020.csv")

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      자전거번호                 대여일시  대여소번호  \
# 0             0           0  SPB-36089  2020-07-01 00:00:54   1734
# 1             1           1  SPB-11402  2020-07-01 00:00:15    610
# 2             2           2  SPB-36935  2020-07-01 00:01:02   3557
# 3             3           3  SPB-35374  2020-07-01 00:00:04    146
# 4             4           4  SPB-37258  2020-07-01 00:01:52   2170
#
#               대여대여소명 대여거치대                 반납일시 반납대여소번호        반납대여소명  반납거치대  \
# 0   쌍문현대1차아파트 108동 앞     0  2020-07-01 00:03:13   01726   삼익세라믹아파트교차로      0
# 1           동대문중 교차로    10  2020-07-01 00:03:23   00657  동대문롯데캐슬아파트 앞      1
# 2  서울숲리버뷰자이APT105동 앞     0  2020-07-01 00:04:15   03511      응봉역 1번출구      0
# 3         마포역 2번출구 뒤     0  2020-07-01 00:04:22   00148    용강동 주민센터 앞      0
# 4           조원동서울본병원     0  2020-07-01 00:04:24   02170      조원동서울본병원      0
#
#    이용시간   이용거리
# 0   2.0    0.0
# 1   3.0  450.0
# 2   3.0    0.0
# 3   4.0    0.0
# 4   3.0    0.0

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', '자전거번호', '대여일시', '대여소번호', '대여대여소명',
#        '대여거치대', '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1, inplace = True)
data.columns
# Out:
# Index(['자전거번호', '대여일시', '대여소번호', '대여대여소명', '대여거치대', '반납일시', '반납대여소번호',
#        '반납대여소명', '반납거치대', '이용시간', '이용거리'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16220857 entries, 0 to 16220856
# Data columns (total 11 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   자전거번호    object
#  1   대여일시     object
#  2   대여소번호    int64
#  3   대여대여소명   object
#  4   대여거치대    object
#  5   반납일시     object
#  6   반납대여소번호  object
#  7   반납대여소명   object
#  8   반납거치대    int64
#  9   이용시간     float64
#  10  이용거리     float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.3+ GB

# %%
data.isnull().sum()
# Out:
# 자전거번호       0
# 대여일시        0
# 대여소번호       0
# 대여대여소명      0
# 대여거치대       0
# 반납일시        0
# 반납대여소번호     0
# 반납대여소명      0
# 반납거치대       0
# 이용시간        0
# 이용거리       93
# dtype: int64

# %%
data[data['이용거리'].isna()]
# Out:
#              자전거번호                 대여일시  대여소번호                  대여대여소명  \
# 18475    SPB-35564  2020-07-01 09:02:37   2191             ?淪筠옥岺關씽?,0"
# 105729   SPB-40728  2020-07-02 00:48:50    500      어린이대공원역 3번출구 ??,0"
# 109613   SPB-33186  2020-07-02 02:28:46   1173           강서구청사거리(SH타워)
# 227978   SPB-36718  2020-07-03 07:50:28   3212                신풍역 6번출구
# 230903   SPB-38671  2020-07-03 08:35:22   2711         가로공원공영주차장 1번 출구
# ...            ...                  ...    ...                     ...
# 4133737  SPB-40881  2020-08-30 12:29:57   1429               장안중?閨?,0"
# 4145465  SPB-33501  2020-08-30 16:09:00   1986             태?贄濚갱爰仟?,0"
# 4157204  SPB-40126  2020-08-30 18:51:43    474  동대문역사문화공원역 1번출구 ?泯?,0"
# 4164064  SPB-41615  2020-08-30 19:14:48    781               신정보도육교 아래
# 4222861  SPB-41542  2020-08-31 18:14:01    972                 ?恥熾?,0"
#
#                        대여거치대                 반납일시                     반납대여소번호  \
# ...

# %%
data[data['이용거리']==0]
# 12789549 개나 이용거리가 0이다.
# Out:
#               자전거번호                 대여일시  대여소번호             대여대여소명 대여거치대  \
# 0         SPB-36089  2020-07-01 00:00:54   1734   쌍문현대1차아파트 108동 앞     0
# 2         SPB-36935  2020-07-01 00:01:02   3557  서울숲리버뷰자이APT105동 앞     0
# 3         SPB-35374  2020-07-01 00:00:04    146         마포역 2번출구 뒤     0
# 4         SPB-37258  2020-07-01 00:01:52   2170           조원동서울본병원     0
# 5         SPB-38382  2020-07-01 00:02:56    650             중랑교사거리     0
# ...             ...                  ...    ...                ...   ...
# 16220850  SPB-33116      2020.6.16 22:13    777        신월6차보람아파트 앞     0
# 16220852  SPB-32717      2020.6.16 22:55    913            이마트 은평점     0
# 16220853  SPB-15338      2020.6.16 22:46    167           연가초등학교 옆    13
# 16220854  SPB-31982      2020.6.16 22:48    559     왕십리역 4번 출구 건너편     0
# 16220856  SPB-14853      2020.6.16 22:35   2115         관악농협농산물백화점    13
#
#                          반납일시 반납대여소번호          반납대여소명  반납거치대  이용시간  이용거리
# ...

# %% [markdown]
# 12789549 개나 이용거리 측정이 안되었다.
# 보간하는 방법이 필요하다.
# 다른 년도는?

# %% [markdown]
# 칼럼을 좀 줄여도 되겠다.

# %%
data.drop('대여대여소명',axis=1,inplace=True)

# %%
data
# Out:
#               자전거번호                 대여일시  이용시간     이용거리
# 0         SPB-36089  2020-07-01 00:00:54   2.0      0.0
# 1         SPB-11402  2020-07-01 00:00:15   3.0    450.0
# 2         SPB-36935  2020-07-01 00:01:02   3.0      0.0
# 3         SPB-35374  2020-07-01 00:00:04   4.0      0.0
# 4         SPB-37258  2020-07-01 00:01:52   3.0      0.0
# ...             ...                  ...   ...      ...
# 16220852  SPB-32717      2020.6.16 22:55   8.0      0.0
# 16220853  SPB-15338      2020.6.16 22:46  17.0      0.0
# 16220854  SPB-31982      2020.6.16 22:48  16.0      0.0
# 16220855  SPB-24981      2020.6.16 22:10  52.0  10290.0
# 16220856  SPB-14853      2020.6.16 22:35  28.0      0.0
#
# [16220857 rows x 4 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
np.mean(data['이용시간'])
# Out:
# 30.14501118097521

# %% [markdown]
# 이용시간의 평균은 30.14501118097521, 약 30분정도이다.

# %%
sns.displot(data['이용시간'])
# Out:
# C:\Users\shjoo\AppData\Roaming\Python\Python38\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\shjoo\AppData\Roaming\Python\Python38\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\shjoo\AppData\Roaming\Python\Python38\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\shjoo\AppData\Roaming\Python\Python38\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\program files\python38\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
# ...
